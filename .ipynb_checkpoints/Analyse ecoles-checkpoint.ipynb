# %%
import numpy as np
import pandas as pd
import re


# Spécification du type de données pour la colonne 'SIREN_SIRET'
df = pd.read_csv('data/ecoles.csv', sep=';', dtype={'SIREN_SIRET': str})
pd.set_option('display.max_columns', 69)
pd.set_option('display.max_rows', 500)

# %%
list(df.columns)
# Out:
# ['Identifiant_de_l_etablissement',
#  'Nom_etablissement',
#  'Type_etablissement',
#  'Statut_public_prive',
#  'Adresse_1',
#  'Adresse_2',
#  'Adresse_3',
#  'Code postal',
#  'Code_commune',
#  'Nom_commune',
#  'Code_departement',
#  'Code_academie',
#  'Code_region',
#  'Ecole_maternelle',
#  'Ecole_elementaire',
#  'Voie_generale',
#  'Voie_technologique',
#  'Voie_professionnelle',
#  'Telephone',
#  'Fax',
#  'Web',
#  'Mail',
#  'Restauration',
#  'Hebergement',
#  'ULIS',
#  'Apprentissage',
#  'Segpa',
#  'Section_arts',
#  'Section_cinema',
#  'Section_theatre',
#  'Section_sport',
#  'Section_internationale',
#  'Section_europeenne',
#  'Lycee_Agricole',
#  'Lycee_militaire',
#  'Lycee_des_metiers',
#  'Post_BAC',
#  'Appartenance_Education_Prioritaire',
#  'GRETA',
#  'SIREN_SIRET',
#  'Nombre_d_eleves',
#  'Fiche_onisep',
#  'position',
#  'Type_contrat_prive',
#  'Libelle_departement',
#  'Libelle_academie',
#  'Libelle_region',
#  'coordonnee_X',
#  'coordonnee_Y',
#  'epsg',
#  'nom_circonscription',
#  'latitude',
#  'longitude',
#  'precision_localisation',
#  'date_ouverture',
#  'date_maj_ligne',
#  'etat',
#  'ministere_tutelle',
#  'etablissement_multi_lignes',
#  'rpi_concentre',
#  'rpi_disperse',
#  'code_nature',
#  'libelle_nature',
#  'Code_type_contrat_prive',
#  'PIAL',
#  'etablissement_mere',
#  'type_rattachement_etablissement_mere',
#  'code_bassin_formation',
#  'libelle_bassin_formation']

# %%
df.head()
# Out:
#   Identifiant_de_l_etablissement                     Nom_etablissement  \
# 0                       0691513V  Ecole élémentaire De Flévieu Le Haut
# 1                       0691541A      Ecole maternelle Edouard Herriot
# 2                       0691579S        Ecole élémentaire Jean d'Azieu
# 3                       0691707F        Ecole maternelle Pablo Picasso
# 4                       0691811U                      Ecole maternelle
#
#   Type_etablissement Statut_public_prive                 Adresse_1 Adresse_2  \
# 0              Ecole              Public  FLEVIEU LE HAUT 35 R BAR       NaN
# 1              Ecole              Public       2 avenue de la Gare       NaN
# 2              Ecole              Public      2 rue Hector Berlioz       NaN
# 3              Ecole              Public  21 avenue de Haute Roche       NaN
# 4              Ecole              Public         Place de la Poste       NaN
#
#              Adresse_3  Code postal Code_commune    Nom_commune  \
# 0         69360 TERNAY        69360        69297         Ternay
# 1      69800 ST PRIEST        69800        69290   Saint-Priest
# 2          69740 GENAS        69740        69277          Genas
# 3  69310 PIERRE BENITE        69310        69152  Pierre-Bénite
# 4      69380 CHATILLON        69380        69050      Châtillon
#
#   Code_departement  Code_academie  Code_region  Ecole_maternelle  \
# 0               69             10           84               0.0
# 1               69             10           84               1.0
# 2               69             10           84               0.0
# 3               69             10           84               1.0
# 4               69             10           84               1.0
#
#    Ecole_elementaire  Voie_generale  Voie_technologique  Voie_professionnelle  \
# 0                1.0            NaN                 NaN                   NaN
# 1                0.0            NaN                 NaN                   NaN
# 2                1.0            NaN                 NaN                   NaN
# 3                0.0            NaN                 NaN                   NaN
# 4                0.0            NaN                 NaN                   NaN
#
#     Telephone  Fax  Web                    Mail  Restauration  Hebergement  \
# 0  0472246566  NaN  NaN  ce.0691513V@ac-lyon.fr           1.0          0.0
# 1  0478205338  NaN  NaN  ce.0691541A@ac-lyon.fr           0.0          0.0
# 2  0478901088  NaN  NaN  ce.0691579S@ac-lyon.fr           1.0          0.0
# 3  0478514099  NaN  NaN  ce.0691707F@ac-lyon.fr           1.0          0.0
# 4  0478439827  NaN  NaN  ce.0691811U@ac-lyon.fr           1.0          0.0
#
#    ULIS  Apprentissage  Segpa  Section_arts  Section_cinema  Section_theatre  \
# 0   0.0            NaN    NaN           NaN             NaN              NaN
# 1   0.0            NaN    NaN           NaN             NaN              NaN
# 2   0.0            NaN    NaN           NaN             NaN              NaN
# 3   0.0            NaN    NaN           NaN             NaN              NaN
# 4   0.0            NaN    NaN           NaN             NaN              NaN
#
#    Section_sport  Section_internationale  Section_europeenne  Lycee_Agricole  \
# 0            NaN                     NaN                 NaN             NaN
# 1            NaN                     NaN                 NaN             NaN
# 2            NaN                     NaN                 NaN             NaN
# 3            NaN                     NaN                 NaN             NaN
# 4            NaN                     NaN                 NaN             NaN
#
#    Lycee_militaire  Lycee_des_metiers  Post_BAC  \
# 0              NaN                NaN       NaN
# 1              NaN                NaN       NaN
# 2              NaN                NaN       NaN
# 3              NaN                NaN       NaN
# 4              NaN                NaN       NaN
#
#   Appartenance_Education_Prioritaire  GRETA     SIREN_SIRET  Nombre_d_eleves  \
# 0                                NaN    NaN  21690297300033            151.0
# 1                                REP    NaN  21690290800161            249.0
# 2                                NaN    NaN  21690277500032            254.0
# 3                               REP+    NaN  21690152000082            281.0
# 4                                NaN    NaN  21690050600033             86.0
#
#   Fiche_onisep                     position Type_contrat_prive  \
# 0          NaN  45.5958162922,4.79882044706         SANS OBJET
# 1          NaN  45.6896866108,4.93524999962         SANS OBJET
# 2          NaN  45.7379654651,5.01247029482         SANS OBJET
# 3          NaN   45.6998794662,4.8296997547         SANS OBJET
# 4          NaN  45.8764480146,4.64486968368         SANS OBJET
#
#   Libelle_departement Libelle_academie        Libelle_region  coordonnee_X  \
# 0               Rhône             Lyon  Auvergne-Rhône-Alpes      840226.4
# 1               Rhône             Lyon  Auvergne-Rhône-Alpes      850604.2
# 2               Rhône             Lyon  Auvergne-Rhône-Alpes      856475.7
# 3               Rhône             Lyon  Auvergne-Rhône-Alpes      842365.4
# 4               Rhône             Lyon  Auvergne-Rhône-Alpes      827577.9
#
#    coordonnee_Y       epsg                                nom_circonscription  \
# 0     6501186.2  EPSG:2154  Circonscription d'inspection du 1er degré de S...
# 1     6511859.0  EPSG:2154  Circonscription d'inspection du 1er degré de S...
# 2     6517368.9  EPSG:2154  Circonscription d'inspection du 1er degré de S...
# 3     6512794.8  EPSG:2154  Circonscription d'inspection du 1er degré de S...
# 4     6532082.2  EPSG:2154  Circonscription d'inspection du 1er degré de l...
#
#     latitude  longitude precision_localisation date_ouverture date_maj_ligne  \
# 0  45.595816    4.79882          Numéro de rue     1965-07-29     2020-10-30
# 1  45.689687    4.93525          Numéro de rue     1965-07-12     2020-10-30
# 2  45.737965    5.01247          Numéro de rue     1965-07-28     2020-10-30
# 3  45.699879    4.82970          Numéro de rue     1969-12-01     2020-10-30
# 4  45.876448    4.64487          Numéro de rue     1970-06-03     2020-10-30
#
#      etat                   ministere_tutelle  etablissement_multi_lignes  \
# 0  OUVERT  MINISTERE DE L'EDUCATION NATIONALE                           0
# 1  OUVERT  MINISTERE DE L'EDUCATION NATIONALE                           0
# 2  OUVERT  MINISTERE DE L'EDUCATION NATIONALE                           0
# 3  OUVERT  MINISTERE DE L'EDUCATION NATIONALE                           0
# 4  OUVERT  MINISTERE DE L'EDUCATION NATIONALE                           0
#
#    rpi_concentre rpi_disperse  code_nature               libelle_nature  \
# 0            0.0          NaN          151  ECOLE DE NIVEAU ELEMENTAIRE
# 1            0.0          NaN          101             ECOLE MATERNELLE
# 2            0.0          NaN          151  ECOLE DE NIVEAU ELEMENTAIRE
# 3            0.0          NaN          101             ECOLE MATERNELLE
# 4            0.0          NaN          101             ECOLE MATERNELLE
#
#    Code_type_contrat_prive      PIAL etablissement_mere  \
# 0                     99.0  0691496B                NaN
# 1                     99.0  0691497C                NaN
# 2                     99.0  0693331W                NaN
# 3                     99.0  0690076H                NaN
# 4                     99.0  0693975W                NaN
#
#   type_rattachement_etablissement_mere code_bassin_formation  \
# 0                                  NaN                 10693
# 1                                  NaN                 10700
# 2                                  NaN                 10695
# 3                                  NaN                 10693
# 4                                  NaN                 10698
#
#   libelle_bassin_formation
# 0                RHONE SUD
# 1            RHONE SUD-EST
# 2            LYON NORD-EST
# 3                RHONE SUD
# 4        MONTS DU LYONNAIS

# %% [markdown]
# #  Filtrage des champs

# %%
df.drop(columns=[
         'Identifiant_de_l_etablissement',
         'Type_etablissement',
         'Adresse_2',
         'Code postal',
         'Code_commune',
         'Nom_commune',
         'Code_academie',
         'Code_region',
         'Ecole_maternelle',
         'Voie_generale',
         'Voie_technologique',
         'Voie_professionnelle',
         'Fax',
         'Web',
         'Restauration',
         'Hebergement',
         'ULIS',
         'Apprentissage',
         'Segpa',
         'Section_arts',
         'Section_cinema',
         'Section_theatre',
         'Section_sport',
         'Section_internationale',
         'Section_europeenne',
         'Lycee_Agricole',
         'Lycee_militaire',
         'Lycee_des_metiers',
         'Post_BAC',
         'Appartenance_Education_Prioritaire',
         'GRETA',
         'SIREN_SIRET',
         'Fiche_onisep',
         'position',
         'Type_contrat_prive',
         'Libelle_departement',
         'Libelle_academie',
         'Libelle_region',
         'coordonnee_X',
         'coordonnee_Y',
         'epsg',
         'nom_circonscription',
         'latitude',
         'longitude',
         'precision_localisation',
         'date_ouverture',
         'date_maj_ligne',
         'etat',
         'ministere_tutelle',
         'etablissement_multi_lignes',
         'rpi_concentre',
         'rpi_disperse',
         'code_nature',
         'libelle_nature',
         'Code_type_contrat_prive',
         'PIAL',
         'etablissement_mere',
         'type_rattachement_etablissement_mere',
         'code_bassin_formation',
         'libelle_bassin_formation'], inplace=True)

# %%
df.head(5)
# Out:
#                       Nom_etablissement Statut_public_prive  \
# 0  Ecole élémentaire De Flévieu Le Haut              Public
# 1      Ecole maternelle Edouard Herriot              Public
# 2        Ecole élémentaire Jean d'Azieu              Public
# 3        Ecole maternelle Pablo Picasso              Public
# 4                      Ecole maternelle              Public
#
#                   Adresse_1            Adresse_3 Code_departement  \
# 0  FLEVIEU LE HAUT 35 R BAR         69360 TERNAY               69
# 1       2 avenue de la Gare      69800 ST PRIEST               69
# 2      2 rue Hector Berlioz          69740 GENAS               69
# 3  21 avenue de Haute Roche  69310 PIERRE BENITE               69
# 4         Place de la Poste      69380 CHATILLON               69
#
#    Ecole_elementaire   Telephone                    Mail  Nombre_d_eleves
# 0                1.0  0472246566  ce.0691513V@ac-lyon.fr            151.0
# 1                0.0  0478205338  ce.0691541A@ac-lyon.fr            249.0
# 2                1.0  0478901088  ce.0691579S@ac-lyon.fr            254.0
# 3                0.0  0478514099  ce.0691707F@ac-lyon.fr            281.0
# 4                0.0  0478439827  ce.0691811U@ac-lyon.fr             86.0

# %% [markdown]
# #  Filtrage écoles élémentaires uniquement

# %%
df['Ecole_elementaire'].value_counts()
# Out:
# 1.0    36966
# 0.0    13665
# Name: Ecole_elementaire, dtype: int64

# %%
filt = (df['Ecole_elementaire'] == 1.0)

# %%
df = df.loc[filt]

# %%
df['Ecole_elementaire'].value_counts()
# Out:
# 1.0    36966
# Name: Ecole_elementaire, dtype: int64

# %% [markdown]
# # Filtrage des adresses mails non valides

# %%
df.shape
# Out:
# (36966, 9)

# %% [markdown]
# On filtre la forme des mails grâce à une regex et on élimine les ecole sans adresse mail.

# %%
mask = df['Mail'].str.contains(r'[^@]+@[^@]+\.[^@]+') & (df['Mail'] != np.nan)
df = df[mask]
df.shape
# Out:
# (36653, 9)

# %%
df['Mail'].str.contains(r'[^@]+@[^@]+\.[^@]+').value_counts()
# Out:
# True    36653
# Name: Mail, dtype: int64

# %% [markdown]
# Il ne reste bien que des école élémentaires au nombre de 36653 (Publiques + privées), avec des emails valides.

# %% [markdown]
# #   Trie par départements

# %%
# Trie par ordre croissant
df = df.sort_values(by='Code_departement')

# %% [markdown]
# # Récupération des données de df en liste

# %%
df['Adresse'] = df['Adresse_1'] + ' ' + df['Adresse_3']

# %%
df.head(1)
# Out:
#                 Nom_etablissement Statut_public_prive   Adresse_1  \
# 40454  ECOLE ELEMENTAIRE PUBLIQUE              Public  Grande rue
#
#               Adresse_3 Code_departement  Ecole_elementaire   Telephone  \
# 40454  01360 BRESSOLLES               01                1.0  0472250117
#
#                          Mail  Nombre_d_eleves                      Adresse
# 40454  ce.0010501P@ac-lyon.fr             97.0  Grande rue 01360 BRESSOLLES

# %% [markdown]
# On enleve les colonnes inutiles

# %%
df = df.drop(columns=['Statut_public_prive', 'Adresse_1', 'Adresse_3', 'Ecole_elementaire', 'Nombre_d_eleves'])

# %%
df.shape
# Out:
# (36653, 5)

# %%
df.head(1)
# Out:
#                 Nom_etablissement Code_departement   Telephone  \
# 40454  ECOLE ELEMENTAIRE PUBLIQUE               01  0472250117
#
#                          Mail                      Adresse
# 40454  ce.0010501P@ac-lyon.fr  Grande rue 01360 BRESSOLLES

# %%
data = df.values.tolist()

# %% [markdown]
# On créer une database avec les champs du formulaire utilisateur google contact depuis nos données sous forme de liste data (plus performant de creer une dataFrame depuis une liste que de creer une dataframe vide puis de l'implementer avec les données d'une autre dataframe)

# %%
df.head(1)
# Out:
#                 Nom_etablissement Code_departement   Telephone  \
# 40454  ECOLE ELEMENTAIRE PUBLIQUE               01  0472250117
#
#                          Mail                      Adresse
# 40454  ce.0010501P@ac-lyon.fr  Grande rue 01360 BRESSOLLES

# %% [markdown]
# | df      | df_contact |
# | ----------- | ----------- |
# | Nom_etablissement      | Name       |
# | Adresse  | Address 1 - Formatted        |
# | Code_departement   | Group Membership        |
# | Telephone   | Phone 1 - Value        |
# | Mail   | E-mail 1 - Value        |

# %%
df_contacts = pd.DataFrame(data, columns=[''])

# %% [markdown]
# # ========= Test d'export en .csv ==========

# %%
df_contact
# Out:
#                                            Name Given Name  Additional Name  \
# 0  préfixe prénonom deuxieme prénom nom suffixe   prénonom  deuxieme prénom
#
#   Family Name  Yomi Name    Given Name Yomi Additional Name Yomi  \
# 0         nom        NaN  prénom phonétique  2 prénom phonétique
#
#   Family Name Yomi Name Prefix Name Suffix  Initials Nickname  Short Name  \
# 0        nom phone     préfixe     suffixe       NaN   pseudo         NaN
#
#    Maiden Name  Birthday  Gender  Location  Billing Information  \
# 0          NaN       NaN     NaN       NaN                  NaN
#
#    Directory Server  Mileage  Occupation  Hobby  Sensitivity  Priority  \
# 0               NaN      NaN         NaN    NaN          NaN       NaN
#
#    Subject          Notes  Language  Photo Group Membership E-mail 1 - Type  \
# 0      NaN  note de texte       NaN    NaN     * myContacts          * Home
#
#   E-mail 1 - Value Phone 1 - Type  Phone 1 - Value  Address 1 - Type  \
# 0   test@gmail.com           Home          8374747               NaN
#
#                                Address 1 - Formatted  \
# 0  36 Avenue du Maréchal de Lattre de Tassigny\n9...
#
#                             Address 1 - Street Address 1 - City  \
# 0  36 Avenue du Maréchal de Lattre de Tassigny           Cachan
#
#    Address 1 - PO Box  Address 1 - Region  Address 1 - Postal Code  \
# 0                 NaN                 NaN                    94230
#
#   Address 1 - Country  Address 1 - Extended Address  Organization 1 - Type  \
# 0                  FR                           NaN                    NaN
#
#   Organization 1 - Name  Organization 1 - Yomi Name Organization 1 - Title  \
# 0            entreprise                         NaN               fonction
#
#    Organization 1 - Department  Organization 1 - Symbol  \
# 0                          NaN                      NaN
#
#    Organization 1 - Location  Organization 1 - Job Description
# 0                        NaN                               NaN

# %%
df_contact = df_contact.append({
        'Name':'test_titre',
        'Address 1 - Formatted': 'test_addr',
        'Group Membership': 'test_group',
        'Phone 1 - Value': '92.43.43.43.43.43-34',
        'E-mail 1 - Value':'testemail.com',
        
    }, ignore_index=True)

# %%
df_contact.to_csv('data/test.csv')

# %% [markdown]
# # ======== Fin du test =========

# %% [markdown]
# # Implementation de la df_contact avec les informations traitées du .csv de l'éducation nationale

# %%
test = {
    'toto': [43, 34, 32],
    'tata': [44, 3, 4],
    'coco':[45, 2, 3], 
}
test2 = ['toto', 'daz', 'ds', 'coco', 'qdssqd', 'tata']
df_1 = pd.DataFrame(test)
df_2 = pd.DataFrame(columns=test2)

# %%
col_to_add = ['ds', 'qdssqd', 'daz']
df_1[col_to_add] = [np.nan for i in range(len(col_to_add))]
df_1
# Out:
#    toto  tata  coco  ds  qdssqd  daz
# 0    43    44    45 NaN     NaN  NaN
# 1    34     3     2 NaN     NaN  NaN
# 2    32     4     3 NaN     NaN  NaN

# %%
df_2
# Out:
# Empty DataFrame
# Columns: [toto, daz, ds, tata, qdssqd, coco]
# Index: []

# %%
df_2.append(df_1)
# Out:
#   toto  daz   ds tata qdssqd coco
# 0   43  NaN  NaN   44    NaN   45
# 1   34  NaN  NaN    3    NaN    2
# 2   32  NaN  NaN    4    NaN    3

# %% [markdown]
# A FAIRE
#
# - changer les noms de colonnes de df pour les meme que df_contact
# - ajouter a df les colones manquante correspondante au champs de df_contact
# - creer df_contacts depuis la liste de colonne de df_contact
# - df_contacts.append(df) pour retrouver l'ordre des champs
# - exporter en csv

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Nom_etablissement, Code_departement, Telephone, Mail, Adresse]
# Index: []

# %%
df_contact.head(0)
# Out:
# Empty DataFrame
# Columns: [Name, Given Name, Additional Name, Family Name, Yomi Name, Given Name Yomi, Additional Name Yomi, Family Name Yomi, Name Prefix, Name Suffix, Initials, Nickname, Short Name, Maiden Name, Birthday, Gender, Location, Billing Information, Directory Server, Mileage, Occupation, Hobby, Sensitivity, Priority, Subject, Notes, Language, Photo, Group Membership, E-mail 1 - Type, E-mail 1 - Value, Phone 1 - Type, Phone 1 - Value, Address 1 - Type, Address 1 - Formatted, Address 1 - Street, Address 1 - City, Address 1 - PO Box, Address 1 - Region, Address 1 - Postal Code, Address 1 - Country, Address 1 - Extended Address, Organization 1 - Type, Organization 1 - Name, Organization 1 - Yomi Name, Organization 1 - Title, Organization 1 - Department, Organization 1 - Symbol, Organization 1 - Location, Organization 1 - Job Description]
# Index: []

# %%
df.columns = ['Name', 'Group Membership', 'Phone 1 - Value', 'E-mail 1 - Value', 'Address 1 - Formatted']

# %%
contact_col = list(df_contact.columns)

# %%
col_a_ajouter
